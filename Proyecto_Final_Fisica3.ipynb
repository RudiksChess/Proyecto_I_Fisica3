# %% [markdown]
# <a href="https://colab.research.google.com/github/RudiksChess/Proyecto_I_Fisica3/blob/master/Proyecto_Final_Fisica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto Final - Física 3
#
#
# $$4$$

# %% [markdown]
# ![Screen Shot 2020-11-20 at 23.27.44.png](data:image/png;base64,...)

# %%
#Partículas predeterminadas

# %%
print("----------------- Espectrómetro de partículas -----------------\n"
      "Seleccione lo que desea hacer:\n\n"
      "1. Agregar partícula\n"
      "2. Disparar partículas\n"
      "3. Cerrar programa")
opcion = int(input("Opción: "))

while opcion != 3:
    if opcion==1: 
         print("----------------- Creador de partículas -----------------")
         electrones = int(input("Electrones:  "))
         neutrones = int(input("Neutrones: "))
         protones = int(input("Protones: "))
    if opcion==2: 
        print("----------------- Simulación -----------------\n\n"
              "NOTA: \n"
              "La simulación permite 1, 2 o 3 partículas ser lanzadas simúltaneamente.")
        cantidad = int(input("Cantidad de partículas: "))

        if cantidad==1: 
          print("algo")

        if cantidad==2: 
          print("algo")
        
        if cantidad==3: 
          print("algo")
      
    else: 
          print("Seleccione un número válido.")



    print("----------------- Espectrómetro de partículas -----------------\n"
      "Seleccione lo que desea hacer:\n\n"
      "1. Agregar partícula\n"
      "2. Disparar partículas\n"
      "3. Cerrar programa")
    opcion = int(input("Opción: "))
# Out:
# ----------------- Espectrómetro de partículas -----------------
# Seleccione lo que desea hacer:
#
# 1. Agregar partícula
# 2. Disparar partículas
# 3. Cerrar programa
# Opción: 3
